# %% [markdown]
# # Run Fun
#
#
# Example
#
# `python ../Fun/Fun calculate-son-score --help
# `

# %%
import bioframe as bf
import subprocess
import cooler
import os

# %% [markdown]
# # Across experiments

# %%
# Shared parameters
resolution = 50000      # 50 kb
ext_length = int(5e6)   # 5 Mb
coverage_ratio = 0 # sparse region threshold (default option)
padding_width = 3 # if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
interval_length = resolution * 5 # ensure it's ~5-fold of resolution as in example
p_value = 0.1
signal_noise_background = 1.3
# HARD-CODED PARAMETER: "--extension_pixels", "10", "100", "5",

# %%
experiments = [
    {
        "hic_file" : "/nfs/turbo/umms-minjilab/downloaded_data/mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool",
        "data_name" : "mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10",
        "genome" : "mm10",
    },
    {
        "hic_file" : "/nfs/turbo/umms-minjilab/downloaded_data/mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool",
        "data_name" : "mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10",
        "genome" : "mm10",
    },
    {
        "hic_file" : "/nfs/turbo/umms-minjilab/downloaded_data/mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool",
        "data_name" : "mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10",
        "genome" : "mm10",
    },
    {
        "hic_file" : "/nfs/turbo/umms-minjilab/downloaded_data/mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool",
        "data_name" : "mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10",
        "genome" : "mm10",
    },
    {
        "hic_file" : "/nfs/turbo/umms-minjilab/downloaded_data/GSE130275_mESC_WT_combined_2.6B.ice.mcool", # micro-C
        "data_name" : "GSE130275_mESC_WT_combined_2.6B",
        "genome" : "mm10",
    },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool",
    #     "data_name": "Repli-HiC_K562_WT_totalS",
    #     "genome": "hg19",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/DP-thymocytes_WT_hic_Guo-2022_GSE199059_mm10-remapped.ice.mcool",
    #     "data_name": "DP-thymocytes_WT_hic_Guo-2022_GSE199059_mm10-remapped",
    #     "genome": "mm10",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/splenic-B-cell_WT_insitu-hic_Kieffer-Kwon-2018_GSE82144_mm9.ice.mcool",
    #     "data_name": "splenic-B-cell_WT_insitu-hic_Kieffer-Kwon-2018_GSE82144_mm9",
    #     "genome": "mm9",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GSE199059_CD69negDPWTR1R2R3R4_merged.ice.mcool",
    #     "data_name": "GSE199059_CD69negDPWTR1R2R3R4_merged",
    #     "genome": "mm9",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_insitu-hic_4DNFI1UEG1HD.ice.mcool",
    #     "data_name": "GM12878_insitu-hic_4DNFI1UEG1HD",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_cohesin-SMC1-RAD21-pooled_chiadrop_Kim-2024_4DNFI9JN3S8M_hg38.ice.mcool",
    #     "data_name": "GM12878_cohesin-SMC1-RAD21-pooled_chiadrop_Kim-2024_4DNFI9JN3S8M_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_CTCF_chiadrop_Kim-2024_4DNFIERR7BI3_hg38.ice.mcool",
    #     "data_name": "GM12878_CTCF_chiadrop_Kim-2024_4DNFIERR7BI3_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_RNAPII_chiadrop_Kim-2024_4DNFI3ZH8UYR_hg38.ice.mcool",
    #     "data_name": "GM12878_RNAPII_chiadrop_Kim-2024_4DNFI3ZH8UYR_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_control_chiapet_Kim-2024_GSE158897-GM19239_hg38.ice.mcool",
    #     "data_name": "GM12878_control_chiapet_Kim-2024_GSE158897-GM19239_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_CTCF_chiapet_Kim-2024_4DNFIR5BPZ5L_hg38.ice.mcool",
    #     "data_name": "GM12878_CTCF_chiapet_Kim-2024_4DNFIR5BPZ5L_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_RAD21_chiapet_Kim-2024_4DNFIV9RG6YP_hg38.ice.mcool",
    #     "data_name": "GM12878_RAD21_chiapet_Kim-2024_4DNFIV9RG6YP_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_RNAPII_chiapet_Kim-2024_4DNFICWBQKM9_hg38.ice.mcool",
    #     "data_name": "GM12878_RNAPII_chiapet_Kim-2024_4DNFICWBQKM9_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/HCT116_RAD21-auxin-0hr_hic_Rao-2017_4DNFIP71EWXC_hg38.ice.mcool",
    #     "data_name": "HCT116_RAD21-auxin-0hr_hic_Rao-2017_4DNFIP71EWXC_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/HCT116_RAD21-auxin-6hr_hic_Rao-2017_4DNFILIM6FDL_hg38.ice.mcool",
    #     "data_name": "HCT116_RAD21-auxin-6hr_hic_Rao-2017_4DNFILIM6FDL_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/HCT116_RAD21-auxin-6hr_intacthic_Guckelberger-2024_ENCFF461RFV_hg38.ice.mcool",
    #     "data_name": "HCT116_RAD21-auxin-6hr_intacthic_Guckelberger-2024_ENCFF461RFV_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/HCT116_RAD21-auxin-0hr_intacthic_Guckelberger-2024_ENCFF109GNA_hg38.ice.mcool",
    #     "data_name": "HCT116_RAD21-auxin-0hr_intacthic_Guckelberger-2024_ENCFF109GNA_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/K562_hic_Rao-2014_4DNFI2R1W3YW_hg38.ice.mcool",
    #     "data_name": "K562_hic_Rao-2014_4DNFI2R1W3YW_hg38",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/zebrafish-embryo_sperm_hic_Wike-2021_4DNFI4P145EM_z11.ice.mcool",
    #     "data_name": "zebrafish-embryo_sperm_hic_Wike-2021_4DNFI4P145EM_z11",
    #     "genome": "danRer11", 
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/c-elegans-CA1200-L2-L3-JK07-JK08_control-auxin-1hr_hic_Kim-2023_GSE188849_ce10.ice.mcool",
    #     "data_name": "c-elegans-CA1200-L2-L3-JK07-JK08_control-auxin-1hr_hic_Kim-2023_GSE188849_ce10",
    #     "genome": "ce10",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/c-elegans-JK05-L3_SMC3-auxin-1hr_hic_Kim-2023_GSE237663_ce10.ice.mcool",
    #     "data_name": "c-elegans-JK05-L3_SMC3-auxin-1hr_hic_Kim-2023_GSE237663_ce10",
    #     "genome": "ce10",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/c-elegans-JK06-L3_WAPL-auxin-1hr_hic_Kim-2023_GSE237663_ce10.ice.mcool",
    #     "data_name": "c-elegans-JK06-L3_WAPL-auxin-1hr_hic_Kim-2023_GSE237663_ce10",
    #     "genome": "ce10",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/GM12878_intacthic_ENCFF785BPC.ice.mcool",
    #     "data_name": "GM12878_intacthic_ENCFF785BPC",
    #     "genome": "hg38",
    # },
    # { # SUCCESSFULLY GENERATED
    #     "hic_file": "/nfs/turbo/umms-minjilab/downloaded_data/K562_intacthic_ENCODE-2023_ENCFF808MAG_hg38.ice.mcool",
    #     "data_name": "K562_intacthic_ENCODE-2023_ENCFF808MAG_hg38",
    #     "genome": "hg38",
    # },
]

# Shared parameters
resolution = 50000      # 50 kb
ext_length = int(5e6)   # 5 Mb
coverage_ratio = 0 # sparse region threshold (default option)
padding_width = 3 # if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
interval_length = resolution * 5 # ensure it's ~5-fold of resolution as in example
p_value = 0.1
signal_noise_background = 1.3
# HARD-CODED PARAMETER: "--extension_pixels", "10", "100", "5", 
base_save_dir = "/nfs/turbo/umms-minjilab/sionkim/jet_pred"

for exp in experiments: 
    hic_file = exp["hic_file"]
    data_name = exp["data_name"]
    genome = exp["genome"]

    save_dir = os.path.join(base_save_dir, f"FUN_{data_name}_{genome}")
    os.makedirs(save_dir, exist_ok=True)

    # Save the chromsizes to a file to give to FUN program
    chromsizes = bf.fetch_chromsizes(genome)
    f_chromsizes = f"{save_dir}/{genome}.chrom.sizes"
    chromsizes.to_csv(f_chromsizes, sep="\t", header=False)

    # Rename chromosomes because FUN requires "1" "2" "3" not "chr1" "chr2" "chr3"
    clr = cooler.Cooler(f"{hic_file}::resolutions/{resolution}", mode="r")

    # Ensure chromosome names do NOT start with "chr"
    rename_dict = {c: c.lstrip("chr") for c in clr.chromnames}
    cooler.rename_chroms(clr, rename_dict)

    cmd = [
        "conda", "run", "-n", "fun-env",  # this is needed to run the command in the FUN conda env
        "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
        "calculate-son-score",  # program name
        f"{hic_file}::resolutions/{resolution}",
        "--out_dir", save_dir,
        "--norm", "weight",
        "--coverage_ratio", f"{coverage_ratio}",  
        "--chromsize_path", f_chromsizes,
        "--ext_length", f"{ext_length}",  # 5 Mb
        "--padding_width", f"{padding_width}",  # if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
        "--offset", f"{resolution}",  # ignore regions too close to the main diagonal (just one bin)
    ]
    subprocess.run(cmd, check=True)

    f_merged_bedgraph = f"{save_dir}/SoN_track_{resolution}/SoN_{resolution}_merged.bedgraph"

    cmd = [
        "conda", "run", "-n", "fun-env",  # this is needed to run the command in the FUN conda env
        "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
        "generate-summits",  # program name
        f"{hic_file}::resolutions/{resolution}",
        "--track", f_merged_bedgraph,
        "--out_dir", save_dir,
    ]
    subprocess.run(cmd, check=True)

    f_merged_summit = f"{save_dir}/SoN_summits/Summits_{resolution}_merged.bed"
    f_output = f"{save_dir}/FUN-pred_{resolution}"

    cmd = [
        "conda", "run", "-n", "fun-env",                # activate the fun-env
        "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
        "find-fountains",                               # program name
        f"{hic_file}::resolutions/{resolution}",
        "--ext_length", f"{ext_length}",  # 5 Mb
        "--norm", "weight",
        "--offset", f"{resolution}",  # ignore regions too close to the main diagonal (just one bin)
        "--coverage_ratio", f"{coverage_ratio}",
        "--half_width", f"{padding_width}",  # (same as --padding_width) if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
        "--region_path", f_merged_summit,     # path to summits
        "--extension_pixels", "10", "100", "5",  # ?
        "--interval_length", f"{interval_length}",  # ensure it's ~5-fold of resolution as in example
        "--output", f_output,
        "--p_value", f"{p_value}",  
        "--signal_noise_background", f"{signal_noise_background}",
    ]
    subprocess.run(cmd, check=True)
# Out:
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome M...
# INFO:cli.calculate_SoN:SoN track for chromosome M written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrM_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_CTCF-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/SoN_50000_merged.bedgraph
#
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome chr1...
# INFO:cli.find_summits:Processing chromosome chr2...
# INFO:cli.find_summits:Processing chromosome chr3...
# INFO:cli.find_summits:Processing chromosome chr4...
# INFO:cli.find_summits:Processing chromosome chr5...
# INFO:cli.find_summits:Processing chromosome chr6...
# INFO:cli.find_summits:Processing chromosome chr7...
# INFO:cli.find_summits:Processing chromosome chr8...
# INFO:cli.find_summits:Processing chromosome chr9...
# INFO:cli.find_summits:Processing chromosome chr10...
# INFO:cli.find_summits:Processing chromosome chr11...
# INFO:cli.find_summits:Processing chromosome chr12...
# INFO:cli.find_summits:Processing chromosome chr13...
# INFO:cli.find_summits:Processing chromosome chr14...
# INFO:cli.find_summits:Processing chromosome chr15...
# INFO:cli.find_summits:Processing chromosome chr16...
# INFO:cli.find_summits:Processing chromosome chr17...
# INFO:cli.find_summits:Processing chromosome chr18...
# INFO:cli.find_summits:Processing chromosome chr19...
# INFO:cli.find_summits:Processing chromosome chrM...
# INFO:cli.find_summits:Processing chromosome chrX...
# INFO:cli.find_summits:Processing chromosome chrY...
#
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!
#
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome M...
# INFO:cli.calculate_SoN:SoN track for chromosome M written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrM_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_RAD21-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/SoN_50000_merged.bedgraph
#
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome 1...
# INFO:cli.find_summits:Processing chromosome 2...
# INFO:cli.find_summits:Processing chromosome 3...
# INFO:cli.find_summits:Processing chromosome 4...
# INFO:cli.find_summits:Processing chromosome 5...
# INFO:cli.find_summits:Processing chromosome 6...
# INFO:cli.find_summits:Processing chromosome 7...
# INFO:cli.find_summits:Processing chromosome 8...
# INFO:cli.find_summits:Processing chromosome 9...
# INFO:cli.find_summits:Processing chromosome 10...
# INFO:cli.find_summits:Processing chromosome 11...
# INFO:cli.find_summits:Processing chromosome 12...
# INFO:cli.find_summits:Processing chromosome 13...
# INFO:cli.find_summits:Processing chromosome 14...
# INFO:cli.find_summits:Processing chromosome 15...
# INFO:cli.find_summits:Processing chromosome 16...
# INFO:cli.find_summits:Processing chromosome 17...
# INFO:cli.find_summits:Processing chromosome 18...
# INFO:cli.find_summits:Processing chromosome 19...
# INFO:cli.find_summits:Processing chromosome M...
# INFO:cli.find_summits:Processing chromosome X...
# INFO:cli.find_summits:Processing chromosome Y...
#
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# /nfs/turbo/umms-minjilab/sionkim/Fun/lib/ks_test.py:25: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   kstest_res = ks_2samp(tkg_plumb_per_dist, bkg_ave)
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!
#
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome M...
# INFO:cli.calculate_SoN:SoN track for chromosome M written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrM_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_WAPL-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/SoN_50000_merged.bedgraph
#
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome 1...
# INFO:cli.find_summits:Processing chromosome 2...
# INFO:cli.find_summits:Processing chromosome 3...
# INFO:cli.find_summits:Processing chromosome 4...
# INFO:cli.find_summits:Processing chromosome 5...
# INFO:cli.find_summits:Processing chromosome 6...
# INFO:cli.find_summits:Processing chromosome 7...
# INFO:cli.find_summits:Processing chromosome 8...
# INFO:cli.find_summits:Processing chromosome 9...
# INFO:cli.find_summits:Processing chromosome 10...
# INFO:cli.find_summits:Processing chromosome 11...
# INFO:cli.find_summits:Processing chromosome 12...
# INFO:cli.find_summits:Processing chromosome 13...
# INFO:cli.find_summits:Processing chromosome 14...
# INFO:cli.find_summits:Processing chromosome 15...
# INFO:cli.find_summits:Processing chromosome 16...
# INFO:cli.find_summits:Processing chromosome 17...
# INFO:cli.find_summits:Processing chromosome 18...
# INFO:cli.find_summits:Processing chromosome 19...
# INFO:cli.find_summits:Processing chromosome M...
# INFO:cli.find_summits:Processing chromosome X...
# INFO:cli.find_summits:Processing chromosome Y...
#
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!
#
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome M...
# INFO:cli.calculate_SoN:SoN track for chromosome M written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrM_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_mESC_YY1-auxin-3hr_microc_Hsieh-2022_GSE178982_mm10_mm10/SoN_track_50000/SoN_50000_merged.bedgraph
#
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome 1...
# INFO:cli.find_summits:Processing chromosome 2...
# INFO:cli.find_summits:Processing chromosome 3...
# INFO:cli.find_summits:Processing chromosome 4...
# INFO:cli.find_summits:Processing chromosome 5...
# INFO:cli.find_summits:Processing chromosome 6...
# INFO:cli.find_summits:Processing chromosome 7...
# INFO:cli.find_summits:Processing chromosome 8...
# INFO:cli.find_summits:Processing chromosome 9...
# INFO:cli.find_summits:Processing chromosome 10...
# INFO:cli.find_summits:Processing chromosome 11...
# INFO:cli.find_summits:Processing chromosome 12...
# INFO:cli.find_summits:Processing chromosome 13...
# INFO:cli.find_summits:Processing chromosome 14...
# INFO:cli.find_summits:Processing chromosome 15...
# INFO:cli.find_summits:Processing chromosome 16...
# INFO:cli.find_summits:Processing chromosome 17...
# INFO:cli.find_summits:Processing chromosome 18...
# INFO:cli.find_summits:Processing chromosome 19...
# INFO:cli.find_summits:Processing chromosome M...
# INFO:cli.find_summits:Processing chromosome X...
# INFO:cli.find_summits:Processing chromosome Y...
#
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!
#
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/GSE130275_mESC_WT_combined_2.6B.ice.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome M...
# INFO:cli.calculate_SoN:SoN track for chromosome M written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chrM_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_GSE130275_mESC_WT_combined_2.6B_mm10/SoN_track_50000/SoN_50000_merged.bedgraph
#
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome 1...
# INFO:cli.find_summits:Processing chromosome 2...
# INFO:cli.find_summits:Processing chromosome 3...
# INFO:cli.find_summits:Processing chromosome 4...
# INFO:cli.find_summits:Processing chromosome 5...
# INFO:cli.find_summits:Processing chromosome 6...
# INFO:cli.find_summits:Processing chromosome 7...
# INFO:cli.find_summits:Processing chromosome 8...
# INFO:cli.find_summits:Processing chromosome 9...
# INFO:cli.find_summits:Processing chromosome 10...
# INFO:cli.find_summits:Processing chromosome 11...
# INFO:cli.find_summits:Processing chromosome 12...
# INFO:cli.find_summits:Processing chromosome 13...
# INFO:cli.find_summits:Processing chromosome 14...
# INFO:cli.find_summits:Processing chromosome 15...
# INFO:cli.find_summits:Processing chromosome 16...
# INFO:cli.find_summits:Processing chromosome 17...
# INFO:cli.find_summits:Processing chromosome 18...
# INFO:cli.find_summits:Processing chromosome 19...
# INFO:cli.find_summits:Processing chromosome M...
# INFO:cli.find_summits:Processing chromosome X...
# INFO:cli.find_summits:Processing chromosome Y...
#
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!

# %%
bf.fetch_chromsizes("ce10")
# Out:
# name
# chrI      15072423
# chrII     15279345
# chrIII    13783700
# chrIV     17493793
# chrV      20924149
# chrX      17718866
# chrM         13794
# Name: length, dtype: int64

# %%
f_chromsizes
# Out:
# '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_c-elegans-JK06-L3_WAPL-auxin-1hr_hic_Kim-2023_GSE237663_ce10_ce10/ce10.chrom.sizes'

# %% [markdown]
# # Individual

# %%
hic_file = "/nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool" 
data_name = "Repli-HiC_K562_WT_totalS"
genome = "hg19"

resolution = 50000  # 50 kb
ext_length = int(5e6) # 5 mb
base_save_dir = "/nfs/turbo/umms-minjilab/sionkim/jet_pred"

save_dir = os.path.join(base_save_dir, f"FUN_{data_name}_{genome}")
os.makedirs(save_dir, exist_ok=True)

# %%
# Save the chromsizes to a file to give to FUN program
chromsizes = bf.fetch_chromsizes(genome)
f_chromsizes = f"{save_dir}/{genome}.chrom.sizes"
chromsizes.to_csv(f_chromsizes, sep="\t", header=False)

# %%
# Rename chromosomes because FUN requires "1" "2" "3" not "chr1" "chr2" "chr3"
clr = cooler.Cooler(f"{hic_file}::resolutions/{resolution}", mode="r")

# Ensure chromosome names do NOT start with "chr"
rename_dict = {c: c.lstrip("chr") for c in clr.chromnames}
cooler.rename_chroms(clr, rename_dict)

# %%
cmd = [
    "conda", "run", "-n", "fun-env", # this is needed to run the command in the FUN conda env
    "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
    "calculate-son-score", # program name
    f"{hic_file}::resolutions/{resolution}",
    "--out_dir", save_dir,
    "--norm", "weight",
    "--coverage_ratio", "0",
    "--chromsize_path", f_chromsizes,
    "--ext_length", f"{ext_length}", # 5 mb
    "--padding_width", "3", # if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
    "--offset", f"{resolution}", # ignore regions too close to the main diagonal (just one bin)
]

subprocess.run(cmd, check=True)
# Out:
# INFO:cli.calculate_SoN:Starting SoN calculation...
# INFO:cli.calculate_SoN:Loading cooler object from /nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool::resolutions/50000...
# INFO:cli.calculate_SoN:Created directory for SoN tracks: /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000
# INFO:cli.calculate_SoN:Processing chromosome 1...
# INFO:cli.calculate_SoN:SoN track for chromosome 1 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr1_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 2...
# INFO:cli.calculate_SoN:SoN track for chromosome 2 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr2_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 3...
# INFO:cli.calculate_SoN:SoN track for chromosome 3 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr3_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 4...
# INFO:cli.calculate_SoN:SoN track for chromosome 4 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr4_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 5...
# INFO:cli.calculate_SoN:SoN track for chromosome 5 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr5_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 6...
# INFO:cli.calculate_SoN:SoN track for chromosome 6 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr6_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 7...
# INFO:cli.calculate_SoN:SoN track for chromosome 7 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr7_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 8...
# INFO:cli.calculate_SoN:SoN track for chromosome 8 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr8_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 9...
# INFO:cli.calculate_SoN:SoN track for chromosome 9 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr9_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 10...
# INFO:cli.calculate_SoN:SoN track for chromosome 10 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr10_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 11...
# INFO:cli.calculate_SoN:SoN track for chromosome 11 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr11_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 12...
# INFO:cli.calculate_SoN:SoN track for chromosome 12 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr12_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 13...
# INFO:cli.calculate_SoN:SoN track for chromosome 13 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr13_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 14...
# INFO:cli.calculate_SoN:SoN track for chromosome 14 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr14_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 15...
# INFO:cli.calculate_SoN:SoN track for chromosome 15 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr15_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 16...
# INFO:cli.calculate_SoN:SoN track for chromosome 16 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr16_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 17...
# INFO:cli.calculate_SoN:SoN track for chromosome 17 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr17_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 18...
# INFO:cli.calculate_SoN:SoN track for chromosome 18 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr18_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 19...
# INFO:cli.calculate_SoN:SoN track for chromosome 19 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr19_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 20...
# INFO:cli.calculate_SoN:SoN track for chromosome 20 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr20_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 21...
# INFO:cli.calculate_SoN:SoN track for chromosome 21 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr21_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome 22...
# INFO:cli.calculate_SoN:SoN track for chromosome 22 written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chr22_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome X...
# INFO:cli.calculate_SoN:SoN track for chromosome X written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chrX_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:Processing chromosome Y...
# INFO:cli.calculate_SoN:SoN track for chromosome Y written to /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/chrY_50000_SoN.bedgraph
# INFO:cli.calculate_SoN:SoN score calculation completed.
# INFO:cli.calculate_SoN:Merging all chromosome tracks into one file...
# INFO:cli.calculate_SoN:Merged bedgraph file created at /nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/SoN_50000_merged.bedgraph
# CompletedProcess(args=['conda', 'run', '-n', 'fun-env', 'python', '/nfs/turbo/umms-minjilab/sionkim/Fun/Fun', 'calculate-son-score', '/nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool::resolutions/50000', '--out_dir', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19', '--norm', 'weight', '--coverage_ratio', '0', '--chromsize_path', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/hg19.chrom.sizes', '--ext_length', '500000', '--padding_width', '3', '--offset', '50000'], returncode=0)

# %%
f_merged_bedgraph = f"{save_dir}/SoN_track_{resolution}/SoN_{resolution}_merged.bedgraph"

cmd = [
    "conda", "run", "-n", "fun-env", # this is needed to run the command in the FUN conda env
    "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
    "generate-summits", # program name
    f"{hic_file}::resolutions/{resolution}",
    "--track", f_merged_bedgraph,
    "--out_dir", save_dir,
]

subprocess.run(cmd, check=True)
# Out:
# INFO:cli.find_summits:Starting Summits detection...
# INFO:cli.find_summits:Processing chromosome 1...
# INFO:cli.find_summits:Processing chromosome 2...
# INFO:cli.find_summits:Processing chromosome 3...
# INFO:cli.find_summits:Processing chromosome 4...
# INFO:cli.find_summits:Processing chromosome 5...
# INFO:cli.find_summits:Processing chromosome 6...
# INFO:cli.find_summits:Processing chromosome 7...
# INFO:cli.find_summits:Processing chromosome 8...
# INFO:cli.find_summits:Processing chromosome 9...
# INFO:cli.find_summits:Processing chromosome 10...
# INFO:cli.find_summits:Processing chromosome 11...
# INFO:cli.find_summits:Processing chromosome 12...
# INFO:cli.find_summits:Processing chromosome 13...
# INFO:cli.find_summits:Processing chromosome 14...
# INFO:cli.find_summits:Processing chromosome 15...
# INFO:cli.find_summits:Processing chromosome 16...
# INFO:cli.find_summits:Processing chromosome 17...
# INFO:cli.find_summits:Processing chromosome 18...
# INFO:cli.find_summits:Processing chromosome 19...
# INFO:cli.find_summits:Processing chromosome 20...
# INFO:cli.find_summits:Processing chromosome 21...
# INFO:cli.find_summits:Processing chromosome 22...
# INFO:cli.find_summits:Processing chromosome X...
# INFO:cli.find_summits:Processing chromosome Y...
# CompletedProcess(args=['conda', 'run', '-n', 'fun-env', 'python', '/nfs/turbo/umms-minjilab/sionkim/Fun/Fun', 'generate-summits', '/nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool::resolutions/50000', '--track', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_track_50000/SoN_50000_merged.bedgraph', '--out_dir', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19'], returncode=0)

# %% [markdown]
# ### Remarks:
#
# Uncertain parameter:
# ```
# --extension_pixels INTEGER...   Array of locations we used to calculate
#                                   dominance in extension. briefly, we just
#                                   need to calculate the dominance at the
#                                   specific pixel's position (for faster speed)
#                                   This param needs further explanation in
#                                   future version...
# ```
#
#
# ERROR: `Error: --signal_noise_background option requires 5 arguments`
#
# ```
#   --signal_noise_background FLOAT...
#                                   The threshold of SoN(fold change) for
#                                   fountains  [default: 1.0]
# ```
# * This bug was fixed (search: `CHANGES 06/18/25 sion kim`)

# %%
f_merged_summit = f"{save_dir}/SoN_summits/Summits_{resolution}_merged.bed"
f_output = f"{save_dir}/FUN-pred_{resolution}"

cmd = [
    "conda", "run", "-n", "fun-env",                # activate the fun-env
    "python", "/nfs/turbo/umms-minjilab/sionkim/Fun/Fun",
    "find-fountains",                               # progrma name
    f"{hic_file}::resolutions/{resolution}",
    "--ext_length", f"{ext_length}", # 5 mb
    "--norm", "weight",
    "--offset", f"{resolution}", # ignore regions too close to the main diagonal (just one bin)
    "--coverage_ratio", "0",
    "--half_width", "3", # (same as --padding_width) if 2, then 2 bin on left and 2 bin on right (total 4 bin width)
    "--region_path", f_merged_summit,     # path to summits
    "--extension_pixels", "10", "100", "5",  # ? 
    "--interval_length", "250000", # ensure its ~5-fold of resolution as in example
    "--output", f_output, 
    "--p_value", "0.1",
    "--signal_noise_background", "1.3", 
]

subprocess.run(cmd, check=True)
# Out:
# INFO:cli.calculate_extension_infor:Starting finding fountains...
# INFO:cli.calculate_extension_infor:Calculate length of fountains and SoN (fold change)...
# INFO:cli.calculate_extension_infor:Perform K-S test...
# INFO:cli.calculate_extension_infor:Perform filter...
# INFO:cli.calculate_extension_infor:Complete!
# CompletedProcess(args=['conda', 'run', '-n', 'fun-env', 'python', '/nfs/turbo/umms-minjilab/sionkim/Fun/Fun', 'find-fountains', '/nfs/turbo/umms-minjilab/downloaded_data/Repli-HiC_K562_WT_totalS.ice.mcool::resolutions/50000', '--ext_length', '5000000', '--norm', 'weight', '--offset', '50000', '--coverage_ratio', '0', '--half_width', '3', '--region_path', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/SoN_summits/Summits_50000_merged.bed', '--extension_pixels', '10', '100', '5', '--interval_length', '250000', '--output', '/nfs/turbo/umms-minjilab/sionkim/jet_pred/FUN_Repli-HiC_K562_WT_totalS_hg19/FUN-pred_50000', '--p_value', '0.1', '--signal_noise_background', '1.3'], returncode=0)
